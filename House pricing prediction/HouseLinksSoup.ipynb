# %%
import requests # type: ignore
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.storia.ro/ro/rezultate/vanzare/casa/bucuresti?limit=72&ownerTypeSingleSelect=ALL&by=LATEST&direction=DESC&page={}"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1'}
result = requests.get(url.format(1), headers=headers)

# %%
soup = BeautifulSoup(result.content.decode(), "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ro">
#  <head data-consent="ignore">
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <link href="https://statics.storia.ro/static/storiaro/naspersclassifieds-regional/verticalsre-atlas-web-storiaro/static/img/favicon.ico?v=5" rel="icon"/>
#   <link href="https://statics.storia.ro/static/storiaro/naspersclassifieds-regional/verticalsre-atlas-web-storiaro/static/img/app-icon.png" rel="apple-touch-icon"/>
#   <link href="https://statics.storia.ro/static/storiaro/naspersclassifieds-regional/verticalsre-atlas-web-storiaro/static/img/app-icon.png" rel="android-touch-icon"/>
#   <meta content="1758851897729052" property="fb:app_id"/>
#   <meta content="https://statics.storia.ro/static/storiaro/naspersclassifieds-regional/verticalsre-atlas-web-storiaro/static/img/fb/fb-image200x200.png?t=20-11-10" property="og:image"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://www.storia.ro/" property="og:url"/>
#   <meta content="www.storia.ro/" property="og:site_name"/>
#   <meta content="https://www.storia.ro/" property="al:web:url"/>
#   <meta content="true" property="al:web:should_fallback"/>
#   <meta content="app-id=ro.storia" name="google-play-app"/>
#   <meta content="#464b53" name="theme-color"/>
#   <meta content="#464b53" name="msapplication-TileColor"/>
#   <link as="font" crossorigin="" href="https://statics.storia.ro/fp_statics/fonts/OpenSans/Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://statics.storia.ro/fp_statics/fonts/OpenSans/SemiBold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://statics.storia.ro/fp_statics/fonts/OpenSans/Bold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://statics.storia.ro/fp_statics/fonts/OpenSans/Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://statics.storia.ro/fp_statics/fonts/OpenSans/SemiBold.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://statics.storia.ro/fp_statics/fonts/OpenSans/Bold.woff2" rel="preload" type="font/woff2"/>
#   <title>
#    Case de vânzare: Bucuresti | Storia.ro
#   </title>
#   <link href="https://www.storia.ro/ro/rezultate/vanzare/casa/bucuresti" rel="canonical"/>
#   <meta content="Case de vânzare: Bucuresti | Storia.ro" property="og:title"/>
#   <meta content="Vezi 1689 anunțuri de case de vânzare în Bucuresti. Găsești această proprietate și multe altele în toată România pe Storia!" name="description"/>
#   <meta content="Vezi 1689 anunțuri de case de vânzare în Bucuresti. Găsești această proprietate și multe altele în toată România pe Storia!" property="og:description"/>
#   <meta content="noindex, follow" name="robots"/>
#   <script type="application/ld+json">
#    {"@context":"https://schema.org","@graph":[{"@type":"WebPage","url":"https://www.storia.ro/ro/rezultate/vanzare/casa/bucuresti","isPartOf":{"@type":"WebSite","name":"Storia.ro","url":"https://www.storia.ro","description":"Descoperă cele mai bune apartamente, case, ansambluri rezidențiale și terenuri din România pe site-ul premium de imobiliare lansat de OLX. Ai de ales între mii de oferte imobiliare. Găsește proprietatea ta de vis pe Storia.ro.","inLanguage":"ro"},"about":{"@type":"Organization","foundingDate":"2016","logo":"https://statics.storia.ro/fp_statics/images/logo/storia_logo_white.svg","brand":"OLX Group","alternateName":["storia ro","storia.ro","storia olx","storia imobiliare","storia. ro","storia romania","www.storia.ro","storia apartamente","storya","storia.ro imobiliare","storia imobiliare bucuresti","storia bucuresti","imobiliare storia","storia agentie imobiliara"],"sameAs":["https://www.facebook.com/storia.ro/","https://www.instagram.com/storia_ro/?hl=en","https://twitter.com/storia_ro","https://www.youtube.com/@Storiaro","https://ro.linkedin.com/company/storia-ro","https://apps.apple.com/es/app/storia-anunturi-imobiliare/id1121617948","https://play.google.com/store/apps/details"],"address":{"@type":"PostalAddress","addressLocality":"București","postalCode":"011141","addressRegion":"București","streetAddress":"Șoseaua Nicolae Titulescu 4-8, etaj 5","addressCountry":{"@type":"Country","name":"România"}},"contactPoint":{"@type":"ContactPoint","telephone":"+40 31 630 13 76","areaServed":"România","contactType":"customer service","availableLanguage":"Română"}},"name":"Case de vânzare: Bucuresti | Storia.ro","description":"Vezi 1689 anunțuri de case de vânzare în Bucuresti. Găsești această proprietate și multe altele în toată România pe Storia!","headline":"Case de vânzare: Bucuresti","primaryImageOfPage":{"@type":"ImageObject","inLanguage":"ro","url":"https://ireland.apollo.olxcdn.com/v1/files/eyJmbiI6Imp2dWN2MnRvemlhbTItQVJPIiwidyI6W3siZm4iOiIzdzU2NnhnanB5MnAxLUFSTyIsInMiOiIxNCIsInAiOiIxMCwtMTAiLCJhIjoiMCJ9XX0.l8WqRp8DwggdDkvOAttw3r-G9zb-UmUFlRZyN0OTwsw/image;s=655x491;q=80","width":"280","height":"208"},"breadcrumb":{"@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.storia.ro/","@type":"WebPage","url":"https://www.storia.ro/","name":"Storia"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.storia.ro/ro/rezultate/vanzare/casa/toata-romania","@type":"WebPage","url":"https://www.storia.ro/ro/rezultate/vanzare/casa/toata-romania","name":"Case de vânzare"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.storia.ro/ro/rezultate/vanzare/casa/bucuresti","@type":"WebPage","url":"https://www.storia.ro/ro/rezultate/vanzare/casa/bucuresti","name":"Bucuresti"}}]}},{"@type":"Product","additionalType":"RealEstateListing","name":"Case de vânzare: Bucuresti | Storia.ro","image":"https://ireland.apollo.olxcdn.com/v1/files/eyJmbiI6Imp2dWN2MnRvemlhbTItQVJPIiwidyI6W3siZm4iOiIzdzU2NnhnanB5MnAxLUFSTyIsInMiOiIxNCIsInAiOiIxMCwtMTAiLCJhIjoiMCJ9XX0.l8WqRp8DwggdDkvOAttw3r-G9zb-UmUFlRZyN0OTwsw/image;s=655x491;q=80","description":"Vezi 1689 anunțuri de case de vânzare în Bucuresti. Găsești această proprietate și multe altele în toată România pe Storia!","url":"https://www.storia.ro/ro/rezultate/vanzare/casa/bucuresti","offers":{"@type":"AggregateOffer","businessFunction":"SELL","highPrice":"7500000","lowPrice":"58400","priceCurrency":"EUR","offerCount":"72","offers":[{"@type":"Offer","availability":"InStock","image":"https://ireland.apollo.olxcdn.com/v1/files/eyJmbiI6Imp2dWN2MnRvemlhbTItQVJPIiwidyI6W3siZm4iOiIzdzU2NnhnanB5MnAxLUFSTyIsInMiOiIxNCIsInAiOiIxMCwtMTAiLCJhIjoiMCJ9XX0.l8WqRp8DwggdDkvOAttw3r-G9zb-UmUFlRZyN0OTwsw/image;s=655x491;q=80","price":215000,"priceCurrency":"EUR","name":"GHENCEA Vila Individuala","url":"https://www.storia.ro/ro/oferta/ghencea-vila-individuala-IDAcWW","itemOffered":{"@type":"SingleFamilyResidence","description":"Vila individuala t ...
#   </script>
#   <link as="image" data-cy="preloaded-search-page-image" href="https://ireland.apollo.olxcdn.com/v1/files/eyJmbiI6IjQ0NGc2N2d6dG14aDMtQVJPIiwidyI6W3siZm4iOiIzdzU2NnhnanB5MnAxLUFSTyIsInMiOiIxNCIsInAiOiIxMCwtMTAiLCJhIjoiMCJ9XX0.rgQ2zeM32yHjCJbnF0-FlfNVLijItMiUQMFE2ktincg/image;s=655x491;q=80" rel="preload"/>
#   <link as="image" data-cy="preloaded-search-page-image" href="https://ireland.apollo.olxcdn.com/v1/files/eyJmbiI6IjIxYzY2ZWJhN2RmcDMtRUNPU1lTVEVNIiwidyI6W3siZm4iOiIzdzU2NnhnanB5MnAxLUFSTyIsInMiOiIxNCIsInAiOiIxMCwtMTAiLCJhIjoiMCJ9XX0.5kNkv5WQFeezgNlEN1e1V4e7kvBkcOR4JDtwdhf3C_4/image;s=655x491;q=80" rel="preload"/>
#   <meta content="30" name="next-head-count"/>
#   <script id="ot-optanonwrapper">
#    function OptanonWrapper() { console.log("[OneTrust] loaded"); }
#   </script>
#   <script id="ot-autoblock" src="https://cdn.cookielaw.org/consent/7f560833-5b7b-488a-8a36-1416bdce0d0e/OtAutoBlock.js">
#   </script>
#   <script data-domain-script="7f560833-5b7b-488a-8a36-1416bdce0d0e" data-language="ro" id="ot-sdk" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js">
#   </script>
#   <link href="https://statics.storia.ro" rel="preconnect"/>
#   <link href="https://statics.storia.ro" rel="dns-prefetch"/>
#   <link href="https://ireland.apollo.olxcdn.com/" rel="preconnect"/>
#   <link href="https://ireland.apollo.olxcdn.com/" rel="dns-prefetch"/>
#   <link as="script" crossorigin="anonymous" href="https://statics.storia.ro/fp_statics/scripts/web-vitals-3.5.2.iife.js" rel="preload"/>
#   <link as="script" href="https://ninja.data.olxcdn.com/ninja-verticals.js" rel="preload"/>
#   <link as="style" href="https://cdn.slots.baxter.olx.org/storiaro/web/release/init.css" rel="preload"/>
#   <link href="https://tracking.olx-st.com/" rel="preconnect"/>
#   <link href="https://tracking.olx-st.com/" rel="dns-prefetch"/>
#   <link href="https://laquesis.data.olxcdn.com/" rel="preconnect"/>
#   <link href="https://laquesis.data.olxcdn.com/" rel="dns-prefetch"/>
#   <link as="style" crossorigin="anonymous" href="https://statics.storia.ro/fp_statics/_next/static/css/c9524fa26080b480.css" rel="preload"/>
#   <link crossorigin="anonymous" data-n-g="" href="https://statics.storia.ro/fp_statics/_next/static/css/c9524fa26080b480.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" nomodule="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5181.484e9de69e1796c5.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5772.abf011214d25bcb2.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/944.bab1b51f890cbdc9.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9018.d11c8ea2c5aa5218.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/7882.e13d82f6e1d0788d.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9915.fdbe23ecf19bcaf0.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/8482.0570d2ab799ad75e.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5722.17f3b7130df746d1.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/webpack-12451e9aafd228e5.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/framework-3682e316793f2296.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/main-d8028843f46d9400.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/pages/_app-1c9c9b22b310e855.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9053-09b6d8962fb90659.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3285-673509c64052a5be.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/8958-d92b8b2353091efc.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9894-2a2d3a5e956741a6.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3524-0a55628b548fb8d2.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/596-47333c13b773f46f.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3451-a5acd70aa64879c3.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9579-9a40ded662a4e1b7.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/6476-3c7dccefd3d1b5fa.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/1112-273d81353d28711c.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9958-599046b587cc9979.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3553-de61393d87d0cb3c.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3978-93d0dd131acb92c2.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/862-327dd5b587299475.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5721-864a734e39ea4212.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3472-d2d78155ba96a394.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/839-675bb99f6bfc01f3.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/1161-28212ecf59ac683b.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5791-df502f285ddee31b.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3854-ba34b058ca18c2d4.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9099-30cdeb306546b54c.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3820-fb1b48106e57e60b.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/3747-77735af6411c3947.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/8797-ad221b7b8419e047.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/873-93af017670970ad4.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5385-9be41e9ab5fb1191.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/424-b4c304467adf5951.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/9483-35a9d3a294a541ab.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5533-52bbda13a5c42b9f.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/5370-be8626ed2755ff72.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/chunks/pages/ro/rezultate/%5B%5B...searchingCriteria%5D%5D-65c04dfbb98b29bb.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/uQCawuN56a2JwrOSu8RYu/_buildManifest.js">
#   </script>
#   <script crossorigin="anonymous" data-ot-ignore="" defer="" src="https://statics.storia.ro/fp_statics/_next/static/uQCawuN56a2JwrOSu8RYu/_ssgManifest.js">
#   </script>
#  </head>
#  <body>
#   <div id="__next">
#    <style data-emotion="css-global m8is4z">
#     @font-face{font-family:'Open Sans';font-weight:400;src:url('https://statics.storia.ro/fp_statics/fonts/OpenSans/Regular.woff2');font-display:swap;}@font-face{font-family:'Open Sans';font-weight:600;src:url('https://statics.storia.ro/fp_statics/fonts/OpenSans/SemiBold.woff2');font-display:swap;}@font-face{font-family:'Open Sans';font-weight:700;src:url('https://statics.storia.ro/fp_statics/fonts/OpenSans/Bold.woff2');font-display:swap;}
#    </style>
#    <style data-emotion="css-global qp6b40">
#     *,*::after,*::before{box-sizing:border-box;}body{margin:0;padding:0;background-color:#fff;color:#1b232e;font-family:Open Sans,Arial,sans-serif;font-size:14px;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;line-height:calc(20 / 14);}input,textarea,button{font-family:inherit;}.onetrust-pc-dark-filter{-webkit-animation:none!important;animation:none!important;-webkit-transition:none!important;transition:none!important;}#onetrust-banner-sdk{bottom:0!important;-webkit-transition:none!important;transition:none!important;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container{padding:16px;width:100%;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy{margin:0;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy #onetrust-policy-title,#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy .ot-dpd-title{font-size:12px;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy #onetrust-policy-title{margin-bottom:0;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy .ot-dpd-title{margin:0;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy p{font-size:10px;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy p#onetrust-policy-text{margin:4px 0 8px;line-height:1.2;}@media (max-width:500px){#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy p#onetrust-policy-text{font-size:12px!important;}}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy p.ot-dpd-desc{margin:4px 0 8px;line-height:1.3;}@media (max-width:500px){#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy p.ot-dpd-desc{font-size:12px!important;}}@media (max-width:500px){#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-group-container #onetrust-policy p{font-size:12px!important;}}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-button-group-parent #onetrust-button-group{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:row-reverse;-ms-flex-direction:row-reverse;flex-direction:row-reverse;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-button-group-parent #onetrust-button-group button{margin-bottom:0;}#onetrust-consent-sdk #onetrust-banner-sdk .ot-sdk-container #onetrust-button-group-parent #onetrust-button-group button#onetrust-accept-btn-handler{margin-right:0;}#onetrust-pc-sdk .ot-btn-container{padding-left:16px;padding-right:16px;}#onetrust-consent-sdk #onetrust-accept-btn-handler,#onetrust-banner-sdk #onetrust-accept-btn-handler,#onetrust-consent-sdk #onetrust-reject-all-handler,#onetrust-banner-sdk #onetrust-reject-all-handler{background-color:#232e3f!important;border-color:#232e3f!important;}#onetrust-banner-sdk.ot-iab-2 #onetrust-button-group button{width:100%;}#onetrust-pc-sdk #ot-pc-content .ot-cat-grp .ot-always-active{color:#00b54b;}#onetrust-pc-sdk #ot-pc-content .ot-tgl input:checked+.ot-switch .ot-switch-nob{background-color:#00b54b;border:1px solid #00b54b;}#onetrust-pc-sdk #ot-pc-content .ot-tgl input:checked+.ot-switch .ot-switch-nob:before{background-color:#fff;border-color:#fff;}#onetrust-pc-sdk #ot-pc-content .ot-tgl input:focus+.ot-switch{outline:#00b54b solid 1px;}#onetrust-pc-sdk #ot-pc-lst .ot-chkbox input:checked~label::before{background-color:#000;}#onetrust-pc-sdk #ot-pc-lst .ot-chkbox label::before{border:1px solid #0 ...
#    </style>
#    <style data-emotion="css-global m8is4z">
#     @font-face{font-family:'Open Sans';font-weight:400;src:url('https://statics.storia.ro/fp_statics/fonts/OpenSans/Regular.woff2');font-display:swap;}@font-face{font-family:'Open Sans';font-weight:600;src:url('https://statics.storia.ro/fp_statics/fonts/OpenSans/SemiBold.woff2');font-display:swap;}@font-face{font-family:'Open Sans';font-weight:700;src:url('https://statics.storia.ro/fp_statics/fonts/OpenSans/Bold.woff2');font-display:swap;}
#    </style>
#    <style data-emotion="css-global 1dudlpk">
#     body{font-family:Open Sans;}
#    </style>
#    <style data-emotion="css 1trt1l5">
#     .css-1trt1l5{display:block!important;max-width:none!important;padding:0!important;border:0!important;border-radius:0!important;background:none!important;box-shadow:none!important;}
#    </style>
#    <div style="position:fixed;z-index:9999">
#    </div>
#    <link href="https://cdn.slots.baxter.olx.org/storiaro/web/release/init.css" id="baxter-style-slots"/>
#    <style data-emotion="css 92dg0j">
#     @media (min-width: 992px){.css-92dg0j{display:none;}}
#    </style>
#    <div class="css-92dg0j enj1nhv0">
#     <style data-emotion="css g3dcc9">
#      .css-g3dcc9{visibility:hidden;position:fixed;z-index:500;inset:0;-webkit-transition:visibility ease-in-out 0.3s,opacity ease-in-out 0.3s;transition:visibility ease-in-out 0.3s,opacity ease-in-out 0.3s;transition-delay:0.1s;opacity:0;background-color:#ffffff;}
#     </style>
#     <div class="css-g3dcc9 egbyzpx3">
#     </div>
#    </div>
#    <style data-emotion="css 1i02l4">
#     .css-1i02l4{display:block;position:relative;overflow-x:hidden;}
#    </style>
#    <div class="css-1i02l4 egbyzpx4">
#     <style data-emotion="css qhweuc">
#      .css-qhweuc{position:absolute;z-index:0;top:0;right:0;left:0;width:0;height:0;margin-left:0;overflow:hidden;opacity:0;}
#     </style>
#     <div class="css-qhweuc ezwsppx0">
#     </div>
#     <style data-emotion="css szdbo9">
#      .css-szdbo9{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;z-index:600;top:0;right:0;left:0;width:100%;border-bottom:1px solid #D3D5D9;background-color:#FFFFFF;color:#071121;}@media (min-width: 992px){.css-szdbo9{padding-top:200px;background-image:none;background-repeat:no-repeat;-webkit-background-position:center top;background-position:center top;}}
#     </style>
#     <div class="css-szdbo9 eku0oc60">
#      <style data-emotion="css zkvd8c">
#       .css-zkvd8c{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-wrap:unset;-webkit-flex-wrap:unset;-ms-flex-wrap:unset;flex-wrap:unset;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;padding:0 4px 0 24px;}@media (min-width: 1280px){.css-zkvd8c{padding:0 24px;}}
#      </style>
#      <style data-emotion="css 1bc7oiu">
#       .css-1bc7oiu{--base:12;--gap:16px;--containerWidth:1280px;margin:auto;max-width:100%;width:var(--containerWidth);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex-wrap:unset;-webkit-flex-wrap:unset;-ms-flex-wrap:unset;flex-wrap:unset;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:start;-ms-flex-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;padding:0 4px 0 24px;}@media (min-width: 1280px){.css-1bc7oiu{padding:0 24px;}}
#      </style>
#      <div class="eku0oc62 css-1bc7oiu">
#       <style data-emotion="css 114aita">
#        .css-114aita{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;width:153px;height:72px;}.css-114aita>img{margin-top:-5px;}
#       </style>
#       <a aria-label="Mergi la pagina principală" class="css-114aita eku0oc61" href="/">
#        <img alt="Mergi la pagina principală" height="30" src="https://statics.storia.ro/fp_statics/images/logo/storia_logo_black.svg" width="108"/>
#       </a>
#       <style data-emotion="css 1ax1yv">
#        .css-1ax1yv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;width:100%;-webkit-transition:opacity 0.2s;transition:opacity 0.2s;opacity:1;}
#       </style>
#       <style data-emotion="css 1d7ri1z">
#        .css-1d7ri1z{--base:12;--gap:16px;--containerWidth:1280px;margin:auto;max-width:100%;width:var(--containerWidth);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:end;-ms-flex-pack:end;-webkit-justify-content:flex-end;justify-content:flex-end;width:100%;-webkit-transition:opacity 0.2s;transition:opacity 0.2s;opacity:1;}
#       </style>
#       <div class="edaxo2a0 css-1d7ri1z">
#        <style data-emotion="css fjtspi">
#         .css-fjtspi{position:relative;width:100%;margin-right:auto;}@media (min-width: 1280px){.css-fjtspi{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:static;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;width:100%;}}
#        </style>
#        <style data-emotion="css 70n85g">
#         .css-70n85g{--base:12;--gap:16px;--containerWidth:1280px;margin:auto;max-width:100%;width:var(--containerWidth);position:relative;width:100%;margin-right:auto;}@media (min-width: 1280px){.css-70n85g{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:static;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;width:100%;}}
#        </style>
#        <div class="edaxo2a1 css-70n85g" data-testid="header-menu">
#         <style data-emotion="css 1ljv5zq">
#          .css-1ljv5zq{display:block;position:fixed;z-index:200;top:0;right:0;bottom:0;width:326px;height:auto;max-height:none;margin:0;padding:24px;overflow:auto;-webkit-transform:translate3d(326px,0,0);-moz-transform:translate3d(326px,0,0);-ms-transform:translate3d(326px,0,0);transform:translate3d(326px,0,0);-webkit-transition:0.2s -webkit-transform ease-in-out;transition:0.2s transform ease-in-out;background-color:#FFFFFF;}.css-1ljv5zq[data-expanded='true']{-webkit-transform:translate3d(0,0,0);-moz-transform:translate3d(0,0,0);-ms-transform:translate3d(0,0,0);transform:translate3d(0,0,0);}@media (min-width: 992px) and (max-width: 1279px){.css-1ljv5zq{position:absolute;top:200px;height:-webkit-fill-available;height:-moz-available;height:fill-available;min-height:640px;}}@media (min-width: 1280px){.css-1ljv5zq{position:unset;width:auto;max-height:340px;padding:0;overflow:unset;-webkit-transform:none;-moz-transform:none;-ms-transform:none;transform:none;}}
#         </style>
#         <div class="css-1ljv5zq e1s5ilqb0" data-expanded="false">
#          <style data-emotion="css 14uqq5i">
#           .css-14uqq5i{color:#071121;position:absolute;z-index:200;top:22px;right:24px;width:32px;height:32px;cursor:pointer;}@media (min-width: 1280px){.css-14uqq5i{display:none;}}
#          </style>
#          <style data-emotion="css 1ruyuv5">
#           .css-1ruyuv5{height:24px;width:24px;color:#1C2637;color:#071121;position:absolute;z-index:200;top:22px;right:24px;width:32px;height:32px;cursor:pointer;}@media (min-width: 1280px){.css-1ruyuv5{display:none;}}
#          </style>
#          <svg aria-label="Închideți navigarea" class="e1s5ilqb7 css-1ruyuv5" data-cy="close-menu-button" fill="none" height="1em" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#           <path clip-rule="evenodd" d="M20.586 2 12 10.585 3.414 2H2v1.414L10.586 12 2 20.586V22h1.414L12 13.414 20.586 22H22v-1.414L13.415 12 22 3.414V2h-1.414Z" fill="currentColor" fill-rule="evenodd">
#           </path>
#          </svg>
#          <style data-emotion="css 70qvj9">
#           .css-70qvj9{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}
#          </style>
#          <nav class="css-70qvj9 e1s5ilqb1">
#           <style data-emotion="css 1y0qrpx">
#            .css-1y0qrpx{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;margin:0;padding:0;list-style:none;}@media (min-width: 1280px){.css-1y0qrpx{z-index:200;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:auto;height:100%;}}
#           </style>
#           <ul class="css-1y0qrpx e1s5ilqb2" role="menu">
#            <li>
#             <style data-emotion="css 1bbw7v7">
#              @media (min-width: 1280px){.css-1bbw7v7{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:static;z-index:1;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:start;-webkit-box-align:start;-ms-flex-align:start;align-items:start;color:#071121;font-weight:400;}}
#             </style>
#             <div class="css-1bbw7v7 e1yg7gwg0" id="sell-container">
#              <style data-emotion="css 1gbarfn">
#               .css-1gbarfn{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:0;background-color:transparent;color:#071121;font-size:16px;line-height:20px;text-align:left;-webkit-text-decoration:none;text-decoration:none;white-space:nowrap;}@media (min-width: 1280px){.css-1gbarfn{z-index:200;padding:20px 8px;background-color:#FFFFFF;font-size:14px;cursor:pointer;}.css-1gbarfn>span{-webkit-flex-basis:min-content;-ms-flex-preferred-size:min-content;flex-basis:min-content;}}
#              </style>
#              <button aria-expanded="false" aria-haspopup="true" class="css-1gbarfn e2561vc0" data-cy="sell" id="sell">
#               <span>
#                De vânzare
#               </span>
#               <style data-emotion="css 1d1uekq">
#                .css-1d1uekq{width:16px;height:16px;margin-left:8px;-webkit-transform:rotate(0);-moz-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);-webkit-transition:-webkit-transform 0.25s ease-in-out;transition:transform 0.25s ease-in-out;}
#               </style>
#               <style data-emotion="css yvrq8u">
#                .css-yvrq8u{height:24px;width:24px;color:#1C2637;width:16px;height:16px;margin-left:8px;-webkit-transform:rotate(0);-moz-transform:rotate(0);-ms-transform:rotate(0);transform:rotate(0);-webkit-transition:-webkit-transform 0.25s ease-in-out;transition:transform 0.25s ease-in-out;}
#               </style>
#               <svg class="e2561vc1 css-yvrq8u" fill="none" height="1em" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M2.001 7h1.414l8.586 8.586L20.587 7h1.414v1.414L12.416 18h-.828L2.001 8.414V7Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#              <style data-emotion="css 156h79b">
#               @media (min-width: 992px){.css-156h79b{display:none;position:absolute;z-index:600;top:100%;left:0;width:100%;border:1px solid #D3D5D9;border-radius:0 0 4px 4px;background-color:#FFFFFF;}}
#              </style>
#              <div class="css-156h79b e155i3us0" data-cy="sellDesktopSubmenu" data-testid="NexusDesktopSubMenuWrapper">
#               <style data-emotion="css cmbq0e">
#                .css-cmbq0e{padding:40px 24px;}
#               </style>
#               <style data-emotion="css oftajj">
#                .css-oftajj{--base:12;--gap:16px;--containerWidth:1280px;margin:auto;max-width:100%;width:var(--containerWidth);padding:40px 24px;}
#               </style>
#               <div class="e155i3us1 css-oftajj">
#                <style data-emotion="css 1gz77k1">
#                 .css-1gz77k1{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;max-width:1400px;padding:0;list-style:none;gap:40px;}
#                </style>
#                <ul class="css-1gz77k1 e155i3us2" role="menu">
#                 <style data-emotion="css 1itn4g7">
#                  .css-1itn4g7{padding-right:40px;}.css-1itn4g7:last-of-type{max-width:360px;padding-right:0;padding-left:40px;border-left:1px solid #D3D5D9;}
#                 </style>
#                 <li class="css-1itn4g7 e155i3us3">
#                  <style data-emotion="css 157aq7f">
#                   .css-157aq7f{margin:0 0 16px 0;color:black;font-size:12px;font-weight:700;line-height:18px;text-transform:uppercase;}
#                  </style>
#                  <p class="css-157aq7f e155i3us4" data-cy="sellEstate">
#                   Proprietăți
#                  </p>
#                  <style data-emotion="css 4oc43e">
#                   .css-4oc43e{padding:0;list-style:none;}
#                  </style>
#                  <ul aria-labelledby="aria-sellEstate" class="css-4oc43e e155i3us5">
#                   <style data-emotion="css o8f9v">
#                    .css-o8f9v:not(:first-of-type){padding:8px 0 0;}
#                   </style>
#                   <li class="css-o8f9v e155i3us6" id="sellEstateApartments">
#                    <style data-emotion="css 8leavu">
#                     @media (min-width: 1280px){.css-8leavu{display:box;-webkit-box-orient:vertical;-webkit-line-clamp:2;margin:8px 0;padding:0;overflow:hidden;border:none;background:none;color:#071121;font-size:14px;font-weight:400;line-height:18px;text-align:start;-webkit-text-decoration:none;text-decoration:none;white-space:pre-wrap;cursor:pointer;}.css-8leavu:hover{-webkit-text-decoration:underline;text-decoration:underline;}.css-8leavu:focus{-webkit-text-decoration:underline;text-decoration:underline;}}
#                    </style>
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstateApartments" href="/ro/rezultate/vanzare/apartament/toata-romania">
#                     Apartamente
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellEstateStudioFlat">
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstateStudioFlat" href="/ro/rezultate/vanzare/garsoniere/toata-romania">
#                     Garsoniere
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellEstateHouse">
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstateHouse" href="/ro/rezultate/vanzare/casa/toata-romania">
#                     Case
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellEstatePlots">
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstatePlots" href="/ro/rezultate/vanzare/teren/toata-romania">
#                     Terenuri
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellEstateCommercials">
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstateCommercials" href="/ro/rezultate/vanzare/spatiu-comercial/toata-romania">
#                     Spații comerciale
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellEstateOffice">
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstateOffice" href="/ro/rezultate/vanzare/spatiu-comercial,birou/toata-romania">
#                     Birouri
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellEstateHalls">
#                    <a class="css-8leavu e155i3us7" data-cy="sellEstateHalls" href="/ro/rezultate/vanzare/depozite-hale/toata-romania">
#                     Hale și depozite
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="css-1itn4g7 e155i3us3">
#                  <p class="css-157aq7f e155i3us4" data-cy="sellPopularLocation">
#                   Locații populare
#                  </p>
#                  <ul aria-labelledby="aria-sellPopularLocation" class="css-4oc43e e155i3us5">
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationBucuresti">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationBucuresti" href="/ro/rezultate/vanzare/apartament/bucuresti">
#                     București
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationIasi">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationIasi" href="/ro/rezultate/vanzare/apartament/iasi">
#                     Iași
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationClujNapoca">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationClujNapoca" href="/ro/rezultate/vanzare/apartament/cluj/cluj--napoca">
#                     Cluj-Napoca
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationTimisoara">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationTimisoara" href="/ro/rezultate/vanzare/apartament/timis/timisoara">
#                     Timișoara
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationConstanta">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationConstanta" href="/ro/rezultate/vanzare/apartament/constanta/constanta">
#                     Constanța
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationCraiova">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationCraiova" href="/ro/rezultate/vanzare/apartament/dolj/craiova">
#                     Craiova
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationBrasov">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationBrasov" href="/ro/rezultate/vanzare/apartament/brasov/brasov">
#                     Brașov
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellPopularLocationGalati">
#                    <a class="css-8leavu e155i3us7" data-cy="sellPopularLocationGalati" href="/ro/rezultate/vanzare/apartament/galati/galati">
#                     Galați
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="css-1itn4g7 e155i3us3">
#                  <p class="css-157aq7f e155i3us4" data-cy="sellInvestment">
#                   Ansambluri
#                  </p>
#                  <ul aria-labelledby="aria-sellInvestment" class="css-4oc43e e155i3us5">
#                   <li class="css-o8f9v e155i3us6" id="sellInvestmentApartment">
#                    <a class="css-8leavu e155i3us7" data-cy="sellInvestmentApartment" href="/ro/rezultate/vanzare/apartament,noi/toata-romania">
#                     Apartamente noi
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellInvestmentHouse">
#                    <a class="css-8leavu e155i3us7" data-cy="sellInvestmentHouse" href="/ro/rezultate/vanzare/casa,noi/toata-romania">
#                     Case noi
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="css-1itn4g7 e155i3us3">
#                  <p class="css-157aq7f e155i3us4" data-cy="sellGuide">
#                   Ghidul cumpărătorului
#                  </p>
#                  <ul aria-labelledby="aria-sellGuide" class="css-4oc43e e155i3us5">
#                   <li class="css-o8f9v e155i3us6" id="sellGuideBuiltArticle">
#                    <a class="css-8leavu e155i3us7" data-cy="sellGuideBuiltArticle" href="https://www.storia.ro/blog/ghid-cumparare/utile/diferenta-dintre-suprafata-construita-si-utila">
#                     Diferența dintre suprafața construită și cea utilă: ce este bine să știi când cumperi sau amenajezi o locuință
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellGuideOldOrNewArticle">
#                    <a class="css-8leavu e155i3us7" data-cy="sellGuideOldOrNewArticle" href="https://www.storia.ro/blog/ghid-cumparare/utile/apartament-bloc-vechi-sau-bloc-nou-avantaje-dezavantaje">
#                     Apartament în bloc vechi sau în bloc nou? Care sunt avantajele și dezavantajele fiecăruia
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="sellGuideFlatsArticle">
#                    <a class="css-8leavu e155i3us7" data-cy="sellGuideFlatsArticle" href="https://www.storia.ro/blog/ghid-cumparare/utile/locuinte-la-parter-avantaje-dezavantaje">
#                     Locuințele la parter – avantaje și dezavantaje
#                    </a>
#                   </li>
#                   <li id="sellGuideSeeAll">
#                    <style data-emotion="css 1uvpwg0">
#                     .css-1uvpwg0{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;margin:8px 0 0;color:#071121;font-size:14px;font-weight:700;line-height:18px;-webkit-text-decoration:none;text-decoration:none;}.css-1uvpwg0:hover{-webkit-text-decoration:underline;text-decoration:underline;cursor:pointer;}
#                    </style>
#                    <a class="css-1uvpwg0 e155i3us8" data-cy="sellGuideSeeAll" data-testid="highlightedLink" href="https://www.storia.ro/blog/ghid-cumparare">
#                     Vezi mai multe
#                     <style data-emotion="css claira">
#                      .css-claira{width:16px;height:16px;margin-left:8px;}
#                     </style>
#                     <style data-emotion="css 76fas4">
#                      .css-76fas4{height:24px;width:24px;color:#1C2637;width:16px;height:16px;margin-left:8px;}
#                     </style>
#                     <svg class="e155i3us10 css-76fas4" fill="none" height="1em" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#                      <path clip-rule="evenodd" d="M8.453 22 18 12.707v-1.414L8.453 2H7v1.414L15.82 12 7 20.586V22h1.453Z" fill="currentColor" fill-rule="evenodd">
#                      </path>
#                     </svg>
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </li>
#            <li>
#             <div class="css-1bbw7v7 e1yg7gwg0" id="rent-container">
#              <button aria-expanded="false" aria-haspopup="true" class="css-1gbarfn e2561vc0" data-cy="rent" id="rent">
#               <span>
#                De închiriat
#               </span>
#               <svg class="e2561vc1 css-yvrq8u" fill="none" height="1em" viewbox="0 0 24 24" width="1em" xmlns="http://www.w3.org/2000/svg">
#                <path clip-rule="evenodd" d="M2.001 7h1.414l8.586 8.586L20.587 7h1.414v1.414L12.416 18h-.828L2.001 8.414V7Z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </button>
#              <div class="css-156h79b e155i3us0" data-cy="rentDesktopSubmenu" data-testid="NexusDesktopSubMenuWrapper">
#               <div class="e155i3us1 css-oftajj">
#                <ul class="css-1gz77k1 e155i3us2" role="menu">
#                 <li class="css-1itn4g7 e155i3us3">
#                  <p class="css-157aq7f e155i3us4" data-cy="rentEstate">
#                   Proprietăți
#                  </p>
#                  <ul aria-labelledby="aria-rentEstate" class="css-4oc43e e155i3us5">
#                   <li class="css-o8f9v e155i3us6" id="rentEstateApartments">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateApartments" href="/ro/rezultate/inchiriere/apartament/toata-romania">
#                     Apartamente
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstateStudioFlat">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateStudioFlat" href="/ro/rezultate/inchiriere/garsoniere/toata-romania">
#                     Garsoniere
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstateHouse">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateHouse" href="/ro/rezultate/inchiriere/casa/toata-romania">
#                     Case
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstateRoom">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateRoom" href="/ro/rezultate/inchiriere/camera/toata-romania">
#                     Camere
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstatePlots">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstatePlots" href="/ro/rezultate/inchiriere/teren/toata-romania">
#                     Terenuri
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstateCommercials">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateCommercials" href="/ro/rezultate/inchiriere/spatiu-comercial/toata-romania">
#                     Spații comerciale
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstateOffice">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateOffice" href="/ro/rezultate/inchiriere/spatiu-comercial,birou/toata-romania">
#                     Birouri
#                    </a>
#                   </li>
#                   <li class="css-o8f9v e155i3us6" id="rentEstateHalls">
#                    <a class="css-8leavu e155i3us7" data-cy="rentEstateHalls" href="/ro/rezultate/inchiriere/depozite-hale/toata-romania">
#                     Hale și depozite
#                    </a>
#                   </li>
#                  </ul>
#                 </li>
#                 <li class="css-1itn4g7 e155i3us3">
#                  <p class="css-157aq7f e155i3us4" data-cy="rentPopularLocation">
#                   Locații populare
#                  </p>
#                  <ul aria-labelledby="aria-rentPopularLocation" class="css-4oc43e e155i3us5">
#                   <li class="css-o8f9v e155i3us6" id="rentPopularLocationBucuresti">
# ...
#              </a>
#             </li>
#             <li class="css-1l95nvm e78vros0">
#              <a class="css-1mxm30b e78vros1" href="https://help.storia.ro/" target="_blank">
#               Ajutor
#              </a>
#             </li>
#             <li class="css-1l95nvm e78vros0">
#              <a class="css-1mxm30b e78vros1" href="https://help.storia.ro/storiahelp/s/topic/0TO09000000kiXCGAY/digital-services-act-dsa" target="_blank">
#               DSA
#              </a>
#             </li>
#            </ul>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#      <style data-emotion="css mdeduj">
#       .css-mdeduj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;min-height:88px;padding:32px 0;border-top:1px solid #D3D5D9;}@media (min-width: 768px){.css-mdeduj{padding:24px 0;}}
#      </style>
#      <div class="css-mdeduj evacg6t1">
#       <style data-emotion="css 1uo6j66">
#        .css-1uo6j66{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:auto;margin:0 auto;}@media (min-width: 992px){.css-1uo6j66{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}}
#       </style>
#       <div class="css-1uo6j66 e10q78bt0">
#        <style data-emotion="css s2c0h3">
#         @media (min-width: 992px){.css-s2c0h3{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;padding:0 16px;}.css-s2c0h3:first-of-type{border-right:1px solid #D3D5D9;}}@media (min-width: 992px){.css-s2c0h3{padding:0 40px;}}
#        </style>
#        <div class="css-s2c0h3 e10q78bt1">
#         <style data-emotion="css xsy1np">
#          .css-xsy1np{margin:0 auto 16px;color:#071121;font-size:12px;font-weight:700;text-align:center;text-transform:uppercase;}@media (min-width: 992px){.css-xsy1np{margin:0 16px 0 0;}}
#         </style>
#         <p class="css-xsy1np e10q78bt2">
#          URMĂREȘTE-NE PE:
#         </p>
#         <style data-emotion="css dbpzdv">
#          .css-dbpzdv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;margin:0;padding:0;list-style:none;}
#         </style>
#         <ul class="css-dbpzdv e10q78bt3">
#          <li class="css-1l95nvm e10q78bt4">
#           <style data-emotion="css z2p32d">
#            .css-z2p32d{display:block;width:24px;height:24px;margin:0 8px 24px;-webkit-transition:background-color 0.2s ease-in-out;transition:background-color 0.2s ease-in-out;background-color:#071121;-webkit-mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/facebook.svg) no-repeat center center;mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/facebook.svg) no-repeat center center;}.css-z2p32d:hover,.css-z2p32d:focus{background-color:#24939E;}@media (min-width: 992px){.css-z2p32d{margin-bottom:0;}}
#           </style>
#           <a class="css-z2p32d e10q78bt6" href="https://www.facebook.com/storia.ro" target="_blank" title="Facebook">
#           </a>
#          </li>
#          <li class="css-1l95nvm e10q78bt4">
#           <style data-emotion="css ptq23y">
#            .css-ptq23y{display:block;width:24px;height:24px;margin:0 8px 24px;-webkit-transition:background-color 0.2s ease-in-out;transition:background-color 0.2s ease-in-out;background-color:#071121;-webkit-mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/youtube.svg) no-repeat center center;mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/youtube.svg) no-repeat center center;}.css-ptq23y:hover,.css-ptq23y:focus{background-color:#24939E;}@media (min-width: 992px){.css-ptq23y{margin-bottom:0;}}
#           </style>
#           <a class="css-ptq23y e10q78bt6" href="https://www.youtube.com/c/Storiaro" target="_blank" title="Youtube">
#           </a>
#          </li>
#          <li class="css-1l95nvm e10q78bt4">
#           <style data-emotion="css 1nhzcun">
#            .css-1nhzcun{display:block;width:24px;height:24px;margin:0 8px 24px;-webkit-transition:background-color 0.2s ease-in-out;transition:background-color 0.2s ease-in-out;background-color:#071121;-webkit-mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/instagram.svg) no-repeat center center;mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/instagram.svg) no-repeat center center;}.css-1nhzcun:hover,.css-1nhzcun:focus{background-color:#24939E;}@media (min-width: 992px){.css-1nhzcun{margin-bottom:0;}}
#           </style>
#           <a class="css-1nhzcun e10q78bt6" href="https://www.instagram.com/storia_ro/" target="_blank" title="Instagram">
#           </a>
#          </li>
#          <li class="css-1l95nvm e10q78bt4">
#           <style data-emotion="css 10fxb57">
#            .css-10fxb57{display:block;width:24px;height:24px;margin:0 8px 24px;-webkit-transition:background-color 0.2s ease-in-out;transition:background-color 0.2s ease-in-out;background-color:#071121;-webkit-mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/tiktok.svg) no-repeat center center;mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/tiktok.svg) no-repeat center center;}.css-10fxb57:hover,.css-10fxb57:focus{background-color:#24939E;}@media (min-width: 992px){.css-10fxb57{margin-bottom:0;}}
#           </style>
#           <a class="css-10fxb57 e10q78bt6" href="https://www.tiktok.com/@storia_ro" target="_blank" title="Tiktok">
#           </a>
#          </li>
#          <li class="css-1l95nvm e10q78bt4">
#           <style data-emotion="css ccii6k">
#            .css-ccii6k{display:block;width:24px;height:24px;margin:0 8px 24px;-webkit-transition:background-color 0.2s ease-in-out;transition:background-color 0.2s ease-in-out;background-color:#071121;-webkit-mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/linkedin.svg) no-repeat center center;mask:url(https://statics.storia.ro/fp_statics/images/pageFooter/socialIcons/linkedin.svg) no-repeat center center;}.css-ccii6k:hover,.css-ccii6k:focus{background-color:#24939E;}@media (min-width: 992px){.css-ccii6k{margin-bottom:0;}}
#           </style>
#           <a class="css-ccii6k e10q78bt6" href="https://www.linkedin.com/company/79635350" target="_blank" title="Linkedin">
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="css-s2c0h3 e10q78bt1">
#         <p class="css-xsy1np e10q78bt2">
#          Aplicații mobile:
#         </p>
#         <ul class="css-dbpzdv e10q78bt3">
#          <li class="css-1l95nvm e10q78bt4">
#           <style data-emotion="css g01tau">
#            .css-g01tau{width:auto;height:40px;margin:0 4px;}.css-g01tau >img{object-fit:contain;width:auto;height:100%;}@media (min-width: 992px){.css-g01tau{margin:0 8px;}}
#           </style>
#           <style data-emotion="css 11d96as">
#            .css-11d96as{display:block;max-width:150px;width:auto;height:40px;margin:0 4px;}.css-11d96as >img{object-fit:contain;width:auto;height:100%;}@media (min-width: 992px){.css-11d96as{margin:0 8px;}}
#           </style>
#           <a class="e10q78bt5 css-11d96as e10zojt30" href="https://apps.apple.com/app/storia/id1121617948">
#            <style data-emotion="css 1ga2hw8">
#             .css-1ga2hw8{display:block;width:100%;object-fit:contain;}
#            </style>
#            <img alt="AppStore" class="css-1ga2hw8 e10zojt31" height="40" loading="lazy" src="https://statics.storia.ro/fp_statics/images/pageFooter/mobileAppsMarkets/app_store.svg" width="131"/>
#           </a>
#          </li>
#          <li class="css-1l95nvm e10q78bt4">
#           <a class="e10q78bt5 css-11d96as e10zojt30" href="https://play.google.com/store/apps/details?id=ro.storia&amp;referrer=utm_source%3Dstoria.ro%26utm_medium%3Dcpc%26utm_campaign%3Dandroid-app-footer">
#            <img alt="Google Play" class="css-1ga2hw8 e10zojt31" height="40" loading="lazy" src="https://statics.storia.ro/fp_statics/images/pageFooter/mobileAppsMarkets/google_play.svg" width="120"/>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#      <div class="css-mdeduj evacg6t1">
#       <style data-emotion="css 1anwktm">
#        .css-1anwktm{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:auto;height:100%;margin:0 auto;}@media (min-width: 992px){.css-1anwktm{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;}}
#       </style>
#       <div class="css-1anwktm e16tb7hg0">
#        <style data-emotion="css w9g0kh">
#         .css-w9g0kh{width:100%;margin:0 0 16px;color:#495260;font-size:12px;text-align:center;white-space:nowrap;}@media (min-width: 992px){.css-w9g0kh{width:auto;margin:0 24px 0 0;}}
#        </style>
#        <p class="css-w9g0kh e16tb7hg1">
#         © 2024 Storia, Grupul OLX
#        </p>
#        <style data-emotion="css 1ri5qyb">
#         .css-1ri5qyb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;max-width:360px;margin:0 auto;padding:0;list-style:none;}@media (min-width: 768px){.css-1ri5qyb{-webkit-box-flex-flow:row nowrap;-webkit-flex-flow:row nowrap;-ms-flex-flow:row nowrap;flex-flow:row nowrap;max-width:none;margin:0;}}
#        </style>
#        <ul class="css-1ri5qyb e16tb7hg2">
#         <style data-emotion="css 1dkks5j">
#          @media (min-width: 768px){.css-1dkks5j:not(:last-of-type){border-right:1px solid #D3D5D9;}}
#         </style>
#         <li class="css-1dkks5j e16tb7hg3">
#          <style data-emotion="css 2xlls7">
#           .css-2xlls7{padding:0 4px;color:#071121;font-size:12px;font-weight:700;-webkit-text-decoration:none;text-decoration:none;text-transform:uppercase;white-space:nowrap;}.css-2xlls7:hover,.css-2xlls7:focus{-webkit-text-decoration:underline;text-decoration:underline;}@media (min-width: 768px){.css-2xlls7{padding:0 8px;cursor:pointer;}}
#          </style>
#          <a class="css-2xlls7 e16tb7hg4" href="https://help.storia.ro/storiahelp/s/topic/0TO09000000kiXAGAY/">
#           Condiții de utilizare
#          </a>
#         </li>
#         <li class="css-1dkks5j e16tb7hg3">
#          <a class="css-2xlls7 e16tb7hg4" href="https://help.storia.ro/storiahelp/s/article/ka009000001weLiAAI">
#           Politica de confidențialitate
#          </a>
#         </li>
#         <li class="css-1dkks5j e16tb7hg3">
#          <style data-emotion="css 1e2qw5v">
#           .css-1e2qw5v{padding:0 4px;color:#071121;font-size:12px;font-weight:700;-webkit-text-decoration:none;text-decoration:none;text-transform:uppercase;white-space:nowrap;border:none;background:none;box-shadow:none;}.css-1e2qw5v:hover,.css-1e2qw5v:focus{-webkit-text-decoration:underline;text-decoration:underline;}@media (min-width: 768px){.css-1e2qw5v{padding:0 8px;cursor:pointer;}}
#          </style>
#          <button class="css-1e2qw5v e16tb7hg5">
#           Setări cookies
#          </button>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </footer>
#    </div>
#    <div>
#    </div>
#   </div>
#   <script crossorigin="anonymous" id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"lang":"ro","_sentryTraceData":"0103c3917677488080a0e60084e94f50-a4ee9684b1bbaa47-0","_sentryBaggage":"sentry-environment=storiaro-prd,sentry-release=frontend-platform%402024-05-09_14.31-storiaro,sentry-public_key=6c4675ab868d06ef702e62aaf3fd60fd,sentry-trace_id=0103c3917677488080a0e60084e94f50,sentry-transaction=%2Fro%2Frezultate%2F%5B%5B...searchingCriteria%5D%5D,sentry-sampled=false","pageTitle":"Case de vânzare: Bucuresti | Storia.ro","pageHeading":"Case de vânzare: Bucuresti","pageDescription":"Vezi 1689 anunțuri de case de vânzare în Bucuresti. Găsești această proprietate și multe altele în toată România pe Storia!","tracking":{"listing":{"cat_l1_id":201,"cat_l1_name":"house","business":"sell","page_nb":1,"page_count":24,"result_count":1689,"results_per_page":72,"listing_format":"list","ad_impressions":[8629527,8629092,8628947,8628679,8628368,8627726,8627436,8627284,8627046,8627020,8627019,8626637,8626222,8625952,8625870,8625842,8625686,8625516,8625104,8624921,8624876,8624711,8624673,8624672,8624614,8624609,8624560,8624554,8624427,8624287,8624221,8624167,8624059,8624049,8624017,8623847,8623618,8623437,8623431,8623420,8623244,8623157,8623078,8622407,8622340,8622106,8621420,8621381,8621172,8621040,8621031,8620975,8620653,8620499,8620461,8620402,8620133,8620058,8619841,8619816,8619815,8619384,8619266,8619244,8618687,8618684,8618668,8617969,8617810,8617779,8617772,8617708,8628679,8575638,8561984],"selected_locations_id":["county:bucuresti"],"market":"primary or secondary","order_by":"latest_desc","re_seller_type":"all"},"search":{"ad_id_selected":null,"ad_inserted_since":null,"building_material":null,"building_type":null,"bungalow":null,"commodity":null,"condition":null,"distance_filt":null,"divisioning_type":null,"exclusive":null,"floor":null,"free_from":null,"from_construction_year":null,"from_height":null,"from_land_area":null,"from_nb_floors":null,"from_price_m2":null,"from_price":null,"from_surface":null,"heating":null,"infrastructure":null,"keyword":null,"main":null,"media":null,"nb_people":null,"nb_rooms":null,"non_smoker":null,"only_open_day":null,"only_private":null,"only_recreation":null,"plot_type":null,"re_seller_type":"all","remote_services":null,"rent_to_students":null,"roof_type":null,"security":null,"selected_locations_id":[],"structure":null,"surroundings":null,"to_construction_year":null,"to_height":null,"to_land_area":null,"to_nb_floors":null,"to_price_m2":null,"to_price":null,"to_surface":null,"use_types":null,"vicinity_types":null,"wc_count":null,"with_3d_view":null,"with_ac":null,"with_balcony":null,"with_cellar":null,"with_garage":null,"with_garden":null,"with_lift":null,"with_maisonette":null,"with_movie":null,"with_parking":null,"with_photo":null,"with_separate_kitchen":null,"with_storage_room":null,"with_terrace":null,"cat_l1_name":"house","cat_l1_id":201,"business":"sell","market":"primary or secondary"}},"targeting":{"env":"production","Country":"Polska","ProperType":"casa","OfferType":"vanzare","City":[],"Market":"ALL","Region":[],"RegularUser":"n","Subregion":["Bucuresti"]},"breadcrumbItems":[{"id":"r1","label":"Storia","url":"/"},{"id":"r2","label":"Case de vânzare","url":"/ro/rezultate/vanzare/casa/toata-romania"},{"id":"location-1","label":"Bucuresti","url":"/ro/rezultate/vanzare/casa/bucuresti"}],"data":{"searchAds":{"__typename":"FoundAds","geometries":["{\"geometry\":{\"coordinates\":[[[25.96600123331882,44.44200211088173],[26.012001235503703,44.444002110976726],[26.019001235836186,44.448002111166716],[26.0140012355987,44.44900211121421],[26.012001235503703,44.452002111356705],[26.012001235503703,44.4550021114992],[26.0140012355987,44.456002111546695],[26.0130012355512,44.45700211159419],[26.00600123521872,44.45700211159419],[25.983001234126277,44.46600211202167],[25.975001233746298,44.46500211197417],[25.975001233746298,44.468002112116665],[25.979001233936287,44.47100211225916],[25.980001233983785,44.480002112686634],[25.983001234126277,44.483002112829126],[25.98 ...
#   </script>
#  </body>
# </html>

# %%
list = []
houses = soup.find_all(attrs={'data-cy':"listing-item-link"})
for house in houses:
    list.append("https://www.storia.ro"+house.get('href'))

# %%
pages = int(soup.find_all(attrs={'class':"css-1tospdx"})[-1].get_text())
print(pages)
# Out:
# 24

# %%
for page in range(2, pages+1):
    result = requests.get(url.format(page), headers=headers)
    soup = BeautifulSoup(result.content.decode(), "html.parser")
    houses = soup.find_all(attrs={'data-cy':"listing-item-link"})
    for house in houses:
        list.append("https://www.storia.ro"+house.get('href'))

# %%
df = pd.DataFrame(list)
print(df)
# Out:
#                                                       0
# 0     https://www.storia.ro/ro/oferta/casa-individua...
# 1     https://www.storia.ro/ro/oferta/vanzari-case-v...
# 2     https://www.storia.ro/ro/oferta/proprietar-vnd...
# 3     https://www.storia.ro/ro/oferta/ghencea-vila-i...
# 4     https://www.storia.ro/ro/oferta/proprietar-pan...
# ...                                                 ...
# 1756  https://www.storia.ro/ro/oferta/unirii-vila-bo...
# 1757  https://www.storia.ro/ro/oferta/vil-cu-6-camer...
# 1758  https://www.storia.ro/ro/oferta/vila-5-camere-...
# 1759  https://www.storia.ro/ro/oferta/turda-parc-reg...
# 1760  https://www.storia.ro/ro/oferta/vila-p-1-singu...
#
# [1761 rows x 1 columns]

# %%
result=df.drop_duplicates(keep="first")
result.to_csv("..\CSVs\Links.csv")
print(result)
# Out:
#                                                       0
# 0     https://www.storia.ro/ro/oferta/casa-individua...
# 1     https://www.storia.ro/ro/oferta/vanzari-case-v...
# 2     https://www.storia.ro/ro/oferta/proprietar-vnd...
# 3     https://www.storia.ro/ro/oferta/ghencea-vila-i...
# 4     https://www.storia.ro/ro/oferta/proprietar-pan...
# ...                                                 ...
# 1756  https://www.storia.ro/ro/oferta/unirii-vila-bo...
# 1757  https://www.storia.ro/ro/oferta/vil-cu-6-camer...
# 1758  https://www.storia.ro/ro/oferta/vila-5-camere-...
# 1759  https://www.storia.ro/ro/oferta/turda-parc-reg...
# 1760  https://www.storia.ro/ro/oferta/vila-p-1-singu...
#
# [1689 rows x 1 columns]
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# <>:2: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Ana\AppData\Local\Temp\ipykernel_14264\349916016.py:2: SyntaxWarning: invalid escape sequence '\C'
#   result.to_csv("..\CSVs\Links.csv")
